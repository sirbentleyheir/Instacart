# %% [markdown]
# <b>Task directions:</b><br>
# 1. Create a new notebook for this task. Be sure to import the relevant libraries, along with your ords_prods_merge dataframe, which should include your newly derived columns from the previous Exercise.<br><br>
# 2. In this Exercise, you learned how to find the aggregated mean of the “order_number” column grouped by “department_id” for a subset of your dataframe. Now, repeat this process for the entire dataframe.<br><br>
# 3. Analyze the result. How do the results for the entire dataframe differ from those of the subset? Include your comments in a markdown cell below the executed code.<br><br>
# 4. Follow the instructions in the Exercise for creating a loyalty flag for existing customers using the transform() and loc() functions.<br><br>
# 5. The marketing team at Instacart wants to know whether there’s a difference between the spending habits of the three types of customers you identified. Use the loyalty flag you created and check the basic statistics of the product prices for each loyalty category (Loyal Customer, Regular Customer, and New Customer). What you’re trying to determine is whether the prices of products purchased by loyal customers differ from those purchased by regular or new customers.<br><br>
# 6. The team now wants to target different types of spenders in their marketing campaigns. This can be achieved by looking at the prices of the items people are buying. Create a spending flag for each user based on the average price across all their orders using the following criteria:<br>
# - If the mean of the prices of products purchased by a user is lower than 10, then flag them as a “Low spender.”<br>
# - If the mean of the prices of products purchased by a user is higher than or equal to 10, then flag them as a “High spender.”<br><br>
# 7. In order to send relevant notifications to users within the app (for instance, asking users if they want to buy the same item again), the Instacart team wants you to determine frequent versus non-frequent customers. Create an order frequency flag that marks the regularity of a user’s ordering behavior according to the median in the “days_since_prior_order” column. The criteria for the flag should be as follows:<br>
# - If the median of “days_since_prior_order” is higher than 20, then the customer should be labeled a “Non-frequent customer.”<br>
# - If the median is higher than 10 and lower than or equal to 20, then the customer should be labeled a “Regular customer.”<br><br>
# - If the median is lower than or equal to 10, then the customer should be labeled a “Frequent customer.” <br>
# 8. Ensure your notebook is clean and structured and that your code is well commented.<br><br>
# 9. Export your dataframe as a pickle file and store it correctly in your “Prepared Data” folder.<br><br>
# 10. Save your notebook and submit it to your tutor for review.

# %% [markdown]
# # Step 1

# %%
# Import libraries 
import pandas as pd
import numpy as np 
import os

# %%
# Create path 
path = r'/Users/bentley/Documents/Instacart'

# %%
# Import a pickle file as a dataframe 
df_ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_derived_new.pkl'))

# %%
# Check shape of dataframe
df_ords_prods_merge.shape
# Out:
# (32404859, 19)

# %%
# View dataframe 
df_ords_prods_merge.head(25)
# Out:
#     order_id  user_id eval_set  order_number  order_day_of_week  \
# 0    2539329        1    prior             1                  2
# 1    2398795        1    prior             2                  3
# 2     473747        1    prior             3                  3
# 3    2254736        1    prior             4                  4
# 4     431534        1    prior             5                  4
# 5    3367565        1    prior             6                  2
# 6     550135        1    prior             7                  1
# 7    3108588        1    prior             8                  1
# 8    2295261        1    prior             9                  1
# 9    2550362        1    prior            10                  4
# 10   2968173       15    prior            15                  1
# 11   1870022       15    prior            17                  2
# 12   1911383       15    prior            18                  2
# 13   2715276       15    prior            21                  1
# 14    487368       15    prior            22                  1
# 15   2293453       19    prior             2                  5
# 16   1973799       19    prior             5                  6
# 17    532817       19    prior             7                  4
# 18   1573906       21    prior            10                  3
# 19   1593000       31    prior            10                  3
# 20   2231262       31    prior            17                  3
# 21   2580647       43    prior             6                  4
# 22   2187180       43    prior             9                  4
# 23   2497897       52    prior             1                  1
# 24   1318871       52    prior             2                  1
#
#     order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                   8                     NaN         196                  1
# 1                   7                    15.0         196                  1
# 2                  12                    21.0         196                  1
# 3                   7                    29.0         196                  1
# 4                  15                    28.0         196                  1
# 5                   7                    19.0         196                  1
# 6                   9                    20.0         196                  1
# 7                  14                    14.0         196                  2
# 8                  16                     0.0         196                  4
# 9                   8                    30.0         196                  1
# 10                  9                     7.0         196                  2
# 11                 16                     8.0         196                  6
# 12                 11                     7.0         196                  1
# 13                  9                     7.0         196                  1
# 14                 10                    14.0         196                  1
# 15                 14                     6.0         196                  3
# 16                 12                     8.0         196                 15
# 17                 17                     6.0         196                  1
# 18                 10                     6.0         196                  2
# 19                  8                     7.0         196                 17
# 20                 11                     8.0         196                 14
# 21                 16                     4.0         196                  9
# 22                 12                     3.0         196                  1
# 23                  9                     NaN         196                  4
# 24                 10                     7.0         196                  5
#
#     reordered _merge product_name  aisle_id  department_id  prices  \
# 0           0   both         Soda        77              7     9.0
# 1           1   both         Soda        77              7     9.0
# 2           1   both         Soda        77              7     9.0
# 3           1   both         Soda        77              7     9.0
# 4           1   both         Soda        77              7     9.0
# 5           1   both         Soda        77              7     9.0
# 6           1   both         Soda        77              7     9.0
# 7           1   both         Soda        77              7     9.0
# 8           1   both         Soda        77              7     9.0
# 9           1   both         Soda        77              7     9.0
# 10          0   both         Soda        77              7     9.0
# 11          1   both         Soda        77              7     9.0
# 12          1   both         Soda        77              7     9.0
# 13          1   both         Soda        77              7     9.0
# 14          1   both         Soda        77              7     9.0
# 15          0   both         Soda        77              7     9.0
# 16          1   both         Soda        77              7     9.0
# 17          1   both         Soda        77              7     9.0
# 18          0   both         Soda        77              7     9.0
# 19          0   both         Soda        77              7     9.0
# 20          1   both         Soda        77              7     9.0
# 21          0   both         Soda        77              7     9.0
# 22          1   both         Soda        77              7     9.0
# 23          0   both         Soda        77              7     9.0
# 24          1   both         Soda        77              7     9.0
#
#       price_range_loc     busiest_day  busiest_days busiest_period_of_day
# 0   Mid-range product  Regularly busy   Normal days        Average orders
# 1   Mid-range product  Regularly busy  Slowest days         Fewest orders
# 2   Mid-range product  Regularly busy  Slowest days           Most orders
# 3   Mid-range product      Least busy  Slowest days         Fewest orders
# 4   Mid-range product      Least busy  Slowest days           Most orders
# 5   Mid-range product  Regularly busy   Normal days         Fewest orders
# 6   Mid-range product  Regularly busy  Busiest days           Most orders
# 7   Mid-range product  Regularly busy  Busiest days           Most orders
# 8   Mid-range product  Regularly busy  Busiest days           Most orders
# 9   Mid-range product      Least busy  Slowest days        Average orders
# 10  Mid-range product  Regularly busy  Busiest days           Most orders
# 11  Mid-range product  Regularly busy   Normal days           Most orders
# 12  Mid-range product  Regularly busy   Normal days           Most orders
# 13  Mid-range product  Regularly busy  Busiest days           Most orders
# 14  Mid-range product  Regularly busy  Busiest days           Most orders
# 15  Mid-range product  Regularly busy   Normal days           Most orders
# 16  Mid-range product  Regularly busy   Normal days           Most orders
# 17  Mid-range product      Least busy  Slowest days           Most orders
# 18  Mid-range product  Regularly busy  Slowest days           Most orders
# 19  Mid-range product  Regularly busy  Slowest days        Average orders
# 20  Mid-range product  Regularly busy  Slowest days           Most orders
# 21  Mid-range product      Least busy  Slowest days           Most orders
# 22  Mid-range product      Least busy  Slowest days           Most orders
# 23  Mid-range product  Regularly busy  Busiest days           Most orders
# 24  Mid-range product  Regularly busy  Busiest days           Most orders

# %% [markdown]
# # Step 2

# %%
# Find the aggregated mean of the "order_number" column grouped by "department_id" 
df_ords_prods_merge.groupby('department_id').agg({'order_number' : ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457838
# 2                17.277920
# 3                17.170395
# 4                17.811403
# 5                15.215751
# 6                16.439806
# 7                17.225802
# 8                15.340650
# 9                15.895474
# 10               20.197148
# 11               16.170638
# 12               15.887671
# 13               16.583536
# 14               16.773669
# 15               16.165037
# 16               17.665606
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %% [markdown]
# # Step 3

# %% [markdown]
# The results for the entire dataframe in Step 2 differ from the subset in the lesson. For instance, in the subset from the lesson, the shape of the subset is limited to 1mil rows. Meanwhile, the entire dataframe (df_ords_prods_merge) run through all 32,404,859 rows which also run through all departments (#21). Because the subset is limited to 1-mil rows, it showed limited results based on departments identified in the first 1-mil rows of the subset (ex: 4, 17, 13, 14, 16, 17, 19, and 20).

# %% [markdown]
# # Step 4

# %% [markdown]
# Establishing Flag Criteria: To create my flag to identify and mark loyal customers who made multiple orders, I need some criteria. I'll use the following... <br>
# - If the max orders the user has made is over 40 <b>(>40)</b>, then the customer will be labeled a 'Loyal customer'<br>
# - If the max orders the user has made is over 10 <b>(40=< >=10)</b>, then the customer will be labeled a 'Regular customer'<br>
#     - If the max orders the user has made is less than or equal to 10 <b>(>=10)</b>, then the customer will be labeled a 'New customer' <br>
# <br>
# Now, let’s map this task onto the three-step process introduced earlier:<br>
# <br>
# Step 1 - Split the data into groups based on the “user_id” column.<br>
# Step 2 - Apply the transform() function on the “order_number” column to generate the maximum orders for each user.<br>
# Step 3 - Create a new column, “max_order,” into which you’ll place the results of your aggregation.<br>
# <br>
# Once this process is complete, I can use the “max_order” column to create another new column that assigns a loyalty flag to each customer according to the criteria (via the loc() function).

# %%
# Complete the 3-step process in a single line of code 
df_ords_prods_merge['max_order'] = df_ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
# Check results in new column 
df_ords_prods_merge.head(20)
# Out:
#     order_id  user_id eval_set  order_number  order_day_of_week  \
# 0    2539329        1    prior             1                  2
# 1    2398795        1    prior             2                  3
# 2     473747        1    prior             3                  3
# 3    2254736        1    prior             4                  4
# 4     431534        1    prior             5                  4
# 5    3367565        1    prior             6                  2
# 6     550135        1    prior             7                  1
# 7    3108588        1    prior             8                  1
# 8    2295261        1    prior             9                  1
# 9    2550362        1    prior            10                  4
# 10   2968173       15    prior            15                  1
# 11   1870022       15    prior            17                  2
# 12   1911383       15    prior            18                  2
# 13   2715276       15    prior            21                  1
# 14    487368       15    prior            22                  1
# 15   2293453       19    prior             2                  5
# 16   1973799       19    prior             5                  6
# 17    532817       19    prior             7                  4
# 18   1573906       21    prior            10                  3
# 19   1593000       31    prior            10                  3
#
#     order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                   8                     NaN         196                  1
# 1                   7                    15.0         196                  1
# 2                  12                    21.0         196                  1
# 3                   7                    29.0         196                  1
# 4                  15                    28.0         196                  1
# 5                   7                    19.0         196                  1
# 6                   9                    20.0         196                  1
# 7                  14                    14.0         196                  2
# 8                  16                     0.0         196                  4
# 9                   8                    30.0         196                  1
# 10                  9                     7.0         196                  2
# 11                 16                     8.0         196                  6
# 12                 11                     7.0         196                  1
# 13                  9                     7.0         196                  1
# 14                 10                    14.0         196                  1
# 15                 14                     6.0         196                  3
# 16                 12                     8.0         196                 15
# 17                 17                     6.0         196                  1
# 18                 10                     6.0         196                  2
# 19                  8                     7.0         196                 17
#
#     reordered _merge product_name  aisle_id  department_id  prices  \
# 0           0   both         Soda        77              7     9.0
# 1           1   both         Soda        77              7     9.0
# 2           1   both         Soda        77              7     9.0
# 3           1   both         Soda        77              7     9.0
# 4           1   both         Soda        77              7     9.0
# 5           1   both         Soda        77              7     9.0
# 6           1   both         Soda        77              7     9.0
# 7           1   both         Soda        77              7     9.0
# 8           1   both         Soda        77              7     9.0
# 9           1   both         Soda        77              7     9.0
# 10          0   both         Soda        77              7     9.0
# 11          1   both         Soda        77              7     9.0
# 12          1   both         Soda        77              7     9.0
# 13          1   both         Soda        77              7     9.0
# 14          1   both         Soda        77              7     9.0
# 15          0   both         Soda        77              7     9.0
# 16          1   both         Soda        77              7     9.0
# 17          1   both         Soda        77              7     9.0
# 18          0   both         Soda        77              7     9.0
# 19          0   both         Soda        77              7     9.0
#
#       price_range_loc     busiest_day  busiest_days busiest_period_of_day  \
# 0   Mid-range product  Regularly busy   Normal days        Average orders
# 1   Mid-range product  Regularly busy  Slowest days         Fewest orders
# 2   Mid-range product  Regularly busy  Slowest days           Most orders
# 3   Mid-range product      Least busy  Slowest days         Fewest orders
# 4   Mid-range product      Least busy  Slowest days           Most orders
# 5   Mid-range product  Regularly busy   Normal days         Fewest orders
# 6   Mid-range product  Regularly busy  Busiest days           Most orders
# 7   Mid-range product  Regularly busy  Busiest days           Most orders
# 8   Mid-range product  Regularly busy  Busiest days           Most orders
# 9   Mid-range product      Least busy  Slowest days        Average orders
# 10  Mid-range product  Regularly busy  Busiest days           Most orders
# 11  Mid-range product  Regularly busy   Normal days           Most orders
# 12  Mid-range product  Regularly busy   Normal days           Most orders
# 13  Mid-range product  Regularly busy  Busiest days           Most orders
# 14  Mid-range product  Regularly busy  Busiest days           Most orders
# 15  Mid-range product  Regularly busy   Normal days           Most orders
# 16  Mid-range product  Regularly busy   Normal days           Most orders
# 17  Mid-range product      Least busy  Slowest days           Most orders
# 18  Mid-range product  Regularly busy  Slowest days           Most orders
# 19  Mid-range product  Regularly busy  Slowest days        Average orders
#
#     max_order
# 0          10
# 1          10
# 2          10
# 3          10
# 4          10
# 5          10
# 6          10
# 7          10
# 8          10
# 9          10
# 10         22
# 11         22
# 12         22
# 13         22
# 14         22
# 15          9
# 16          9
# 17          9
# 18         33
# 19         20

# %% [markdown]
# Notes: a new column ("max_order") has been created. Next, I can assign a new column ("loyalty_flag") to it based on the flag criteria.

# %%
# Create a flag that assigns a "loyalty" label to a user ID based on its corresponding max order value 
df_ords_prods_merge.loc[df_ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
df_ords_prods_merge.loc[(df_ords_prods_merge['max_order'] <=40) & (df_ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
df_ords_prods_merge.loc[df_ords_prods_merge['max_order'] <=10, 'loyalty_flag'] = 'New customer'

# %%
# Print frequency of the new "loyalty_flag" column using the value_counts() function 
df_ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: loyalty_flag, dtype: int64

# %% [markdown]
# Notes: Most of the customers fall under the "Regular customer" category which makes sense.

# %% [markdown]
# # Step 5

# %%
# Check information about the dataframe 
df_ords_prods_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32404859 entries, 0 to 32404858
# Data columns (total 21 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                int64
#  1   user_id                 int64
#  2   eval_set                object
#  3   order_number            int64
#  4   order_day_of_week       int64
#  5   order_hour_of_day       int64
#  6   days_since_prior_order  float64
#  7   product_id              int64
#  8   add_to_cart_order       int64
#  9   reordered               int64
#  10  _merge                  category
#  11  product_name            object
#  12  aisle_id                int64
#  13  department_id           int64
#  14  prices                  float64
#  15  price_range_loc         object
#  16  busiest_day             object
#  17  busiest_days            object
#  18  busiest_period_of_day   object
#  19  max_order               int64
#  20  loyalty_flag            object
# dtypes: category(1), float64(2), int64(11), object(7)
# memory usage: 6.4+ GB

# %% [markdown]
# For this step, I'll need to use the "loyalty_flag" and "prices" columns.

# %%
# Check basic, multiple statistics about 3 types of customers and their spending habits 
df_ords_prods_merge.groupby('loyalty_flag').agg({'prices': ['mean', 'min', 'max']})
# Out:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer    10.386336  1.0  99999.0
# New customer      13.294670  1.0  99999.0
# Regular customer  12.495717  1.0  99999.0

# %% [markdown]
# Notes: Loyal customers spend less on average compared to the other two types of customers. New and regular customers spend nearly the same amount of money purchased via Instacart.

# %% [markdown]
# # Step 6

# %% [markdown]
# Establishing Spending Flag Criteria: <br>
# To create my "spending_flag" to identify and label types of spenders (Low spender/High spender), I need some criteria. I'll look at the prices of the items people are buying and create a spending flag for each user based on the average price across all their orders using the following: <br>
# <br>
# - If the mean of the prices of products purchased by a user is lower than 10 <b>(<10)</b>, then I'll flag them as a 'Low spender'<br>
# - If the mean of the prices of products purchased by a user is higher than or equal to 10 <b>(>=10)</b>, then I'll flag them as a 'High spender'
# <br><br>
# I'll use the 3-step process as outlined in Step 4 to compute Step 6. <br>
# Step 1 - Split the data into groups based on the “user_id” column.<br>
# Step 2 - Apply the transform() function on the “prices” column to generate the average orders for each user.<br>
# Step 3 - Create a new column, “spending_habits,” into which I’ll place the results of my aggregation.<br>
# <br>
# Once this process is complete, I can use the “spending_habits” column to create another new column that assigns a spending flag to each customer according to the criteria (via the loc() function).

# %%
# Complete the 3-step process in a single line of code 
df_ords_prods_merge['spending_habits'] = df_ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
# Check results in new column 
df_ords_prods_merge.head(10)
# Out:
#    order_id  user_id eval_set  order_number  order_day_of_week  \
# 0   2539329        1    prior             1                  2
# 1   2398795        1    prior             2                  3
# 2    473747        1    prior             3                  3
# 3   2254736        1    prior             4                  4
# 4    431534        1    prior             5                  4
# 5   3367565        1    prior             6                  2
# 6    550135        1    prior             7                  1
# 7   3108588        1    prior             8                  1
# 8   2295261        1    prior             9                  1
# 9   2550362        1    prior            10                  4
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  7                    15.0         196                  1
# 2                 12                    21.0         196                  1
# 3                  7                    29.0         196                  1
# 4                 15                    28.0         196                  1
# 5                  7                    19.0         196                  1
# 6                  9                    20.0         196                  1
# 7                 14                    14.0         196                  2
# 8                 16                     0.0         196                  4
# 9                  8                    30.0         196                  1
#
#    reordered  ... aisle_id department_id  prices    price_range_loc  \
# 0          0  ...       77             7     9.0  Mid-range product
# 1          1  ...       77             7     9.0  Mid-range product
# 2          1  ...       77             7     9.0  Mid-range product
# 3          1  ...       77             7     9.0  Mid-range product
# 4          1  ...       77             7     9.0  Mid-range product
# 5          1  ...       77             7     9.0  Mid-range product
# 6          1  ...       77             7     9.0  Mid-range product
# 7          1  ...       77             7     9.0  Mid-range product
# 8          1  ...       77             7     9.0  Mid-range product
# 9          1  ...       77             7     9.0  Mid-range product
#
#       busiest_day  busiest_days busiest_period_of_day max_order  loyalty_flag  \
# 0  Regularly busy   Normal days        Average orders        10  New customer
# 1  Regularly busy  Slowest days         Fewest orders        10  New customer
# 2  Regularly busy  Slowest days           Most orders        10  New customer
# 3      Least busy  Slowest days         Fewest orders        10  New customer
# 4      Least busy  Slowest days           Most orders        10  New customer
# 5  Regularly busy   Normal days         Fewest orders        10  New customer
# 6  Regularly busy  Busiest days           Most orders        10  New customer
# 7  Regularly busy  Busiest days           Most orders        10  New customer
# 8  Regularly busy  Busiest days           Most orders        10  New customer
# 9      Least busy  Slowest days        Average orders        10  New customer
#
#    spending_habits
# 0         6.367797
# 1         6.367797
# 2         6.367797
# 3         6.367797
# 4         6.367797
# 5         6.367797
# 6         6.367797
# 7         6.367797
# 8         6.367797
# 9         6.367797
#
# [10 rows x 22 columns]

# %% [markdown]
# Notes: The new column "spending_habits" has been created and cells are computed. Next, I'll check again by viewing the first 75 rows of the dataframe.

# %%
# Recheck results in new column 
df_ords_prods_merge.head(75)
# Out:
#     order_id  user_id eval_set  order_number  order_day_of_week  \
# 0    2539329        1    prior             1                  2
# 1    2398795        1    prior             2                  3
# 2     473747        1    prior             3                  3
# 3    2254736        1    prior             4                  4
# 4     431534        1    prior             5                  4
# ..       ...      ...      ...           ...                ...
# 70   2846344       98    prior            11                  4
# 71    747431       98    prior            12                  6
# 72   2383054       98    prior            13                  4
# 73   1993729       98    prior            14                  5
# 74   1403849      109    prior             3                  3
#
#     order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                   8                     NaN         196                  1
# 1                   7                    15.0         196                  1
# 2                  12                    21.0         196                  1
# 3                   7                    29.0         196                  1
# 4                  15                    28.0         196                  1
# ..                ...                     ...         ...                ...
# 70                 13                    15.0         196                  2
# 71                 13                    30.0         196                  4
# 72                 11                    30.0         196                  1
# 73                  8                     8.0         196                  2
# 74                 17                     9.0         196                  5
#
#     reordered  ... aisle_id department_id  prices    price_range_loc  \
# 0           0  ...       77             7     9.0  Mid-range product
# 1           1  ...       77             7     9.0  Mid-range product
# 2           1  ...       77             7     9.0  Mid-range product
# 3           1  ...       77             7     9.0  Mid-range product
# 4           1  ...       77             7     9.0  Mid-range product
# ..        ...  ...      ...           ...     ...                ...
# 70          1  ...       77             7     9.0  Mid-range product
# 71          1  ...       77             7     9.0  Mid-range product
# 72          1  ...       77             7     9.0  Mid-range product
# 73          1  ...       77             7     9.0  Mid-range product
# 74          0  ...       77             7     9.0  Mid-range product
#
#        busiest_day  busiest_days busiest_period_of_day max_order  \
# 0   Regularly busy   Normal days        Average orders        10
# 1   Regularly busy  Slowest days         Fewest orders        10
# 2   Regularly busy  Slowest days           Most orders        10
# 3       Least busy  Slowest days         Fewest orders        10
# 4       Least busy  Slowest days           Most orders        10
# ..             ...           ...                   ...       ...
# 70      Least busy  Slowest days           Most orders        14
# 71  Regularly busy   Normal days           Most orders        14
# 72      Least busy  Slowest days           Most orders        14
# 73  Regularly busy   Normal days        Average orders        14
# 74  Regularly busy  Slowest days           Most orders         6
#
#         loyalty_flag  spending_habits
# 0       New customer         6.367797
# 1       New customer         6.367797
# 2       New customer         6.367797
# 3       New customer         6.367797
# 4       New customer         6.367797
# ..               ...              ...
# 70  Regular customer         8.028000
# 71  Regular customer         8.028000
# 72  Regular customer         8.028000
# 73  Regular customer         8.028000
# 74      New customer         5.850725
#
# [75 rows x 22 columns]

# %%
# Command pandas not to assign any options regarding the max number of rows to display 
pd.options.display.max_rows = None

# %%
# Rerun the recheck results in new column 
df_ords_prods_merge.head(75)
# Out:
#     order_id  user_id eval_set  order_number  order_day_of_week  \
# 0    2539329        1    prior             1                  2
# 1    2398795        1    prior             2                  3
# 2     473747        1    prior             3                  3
# 3    2254736        1    prior             4                  4
# 4     431534        1    prior             5                  4
# 5    3367565        1    prior             6                  2
# 6     550135        1    prior             7                  1
# 7    3108588        1    prior             8                  1
# 8    2295261        1    prior             9                  1
# 9    2550362        1    prior            10                  4
# 10   2968173       15    prior            15                  1
# 11   1870022       15    prior            17                  2
# 12   1911383       15    prior            18                  2
# 13   2715276       15    prior            21                  1
# 14    487368       15    prior            22                  1
# 15   2293453       19    prior             2                  5
# 16   1973799       19    prior             5                  6
# 17    532817       19    prior             7                  4
# 18   1573906       21    prior            10                  3
# 19   1593000       31    prior            10                  3
# 20   2231262       31    prior            17                  3
# 21   2580647       43    prior             6                  4
# 22   2187180       43    prior             9                  4
# 23   2497897       52    prior             1                  1
# 24   1318871       52    prior             2                  1
# 25   1261384       52    prior             3                  1
# 26    580568       52    prior             5                  2
# 27   2428073       52    prior             7                  2
# 28    342306       52    prior             9                  1
# 29   1520353       52    prior            10                  2
# 30   2542086       52    prior            11                  2
# 31    944694       52    prior            12                  1
# 32   1268191       52    prior            15                  2
# 33   1122089       52    prior            17                  2
# 34   1498922       52    prior            18                  2
# 35    180919       52    prior            19                  3
# 36   2695875       52    prior            21                  5
# 37   3205960       67    prior             1                  3
# 38    970922       67    prior             2                  1
# 39    596585       67    prior             3                  1
# 40   2037087       67    prior             4                  2
# 41   2474111       67    prior             5                  3
# 42   1568481       67    prior             6                  3
# 43   2048527       67    prior             8                  2
# 44   2389031       67    prior             9                  2
# 45   2378562       67    prior            10                  1
# 46   1515698       67    prior            11                  1
# 47   1928050       67    prior            12                  2
# 48   1949274       67    prior            13                  1
# 49    551869       67    prior            14                  1
# 50    768572       67    prior            16                  4
# 51    150528       67    prior            18                  5
# 52     29758       67    prior            19                  0
# 53   1558976       67    prior            21                  1
# 54    863974       67    prior            22                  1
# 55   2308399       67    prior            23                  1
# 56   2759128       81    prior             3                  1
# 57   1812985       81    prior             5                  2
# 58   1889835       82    prior             1                  3
# 59    499460       82    prior             3                  5
# 60   2728456       82    prior             4                  0
# 61   2653743       82    prior             6                  4
# 62   1358880       82    prior             9                  1
# 63    343588       82    prior            10                  2
# 64   3034663       82    prior            15                  2
# 65    147262       82    prior            18                  1
# 66   3144004       82    prior            19                  2
# 67   2126069       98    prior             3                  0
# 68   2210120       98    prior             7                  5
# 69    681011       98    prior             9                  3
# 70   2846344       98    prior            11                  4
# 71    747431       98    prior            12                  6
# 72   2383054       98    prior            13                  4
# 73   1993729       98    prior            14                  5
# 74   1403849      109    prior             3                  3
#
#     order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                   8                     NaN         196                  1
# 1                   7                    15.0         196                  1
# 2                  12                    21.0         196                  1
# 3                   7                    29.0         196                  1
# 4                  15                    28.0         196                  1
# 5                   7                    19.0         196                  1
# 6                   9                    20.0         196                  1
# 7                  14                    14.0         196                  2
# 8                  16                     0.0         196                  4
# 9                   8                    30.0         196                  1
# 10                  9                     7.0         196                  2
# 11                 16                     8.0         196                  6
# 12                 11                     7.0         196                  1
# 13                  9                     7.0         196                  1
# 14                 10                    14.0         196                  1
# 15                 14                     6.0         196                  3
# 16                 12                     8.0         196                 15
# 17                 17                     6.0         196                  1
# 18                 10                     6.0         196                  2
# 19                  8                     7.0         196                 17
# 20                 11                     8.0         196                 14
# 21                 16                     4.0         196                  9
# 22                 12                     3.0         196                  1
# 23                  9                     NaN         196                  4
# 24                 10                     7.0         196                  5
# 25                 10                     7.0         196                  3
# 26                 10                     8.0         196                  6
# 27                  7                     8.0         196                  5
# 28                 11                     7.0         196                  5
# 29                 10                     8.0         196                  4
# 30                  9                     7.0         196                  3
# 31                 16                     6.0         196                  7
# 32                 11                     8.0         196                  3
# 33                 10                     6.0         196                  4
# 34                 10                    14.0         196                  6
# 35                  8                     8.0         196                  4
# 36                 10                    30.0         196                  1
# 37                 11                     NaN         196                  1
# 38                 15                     5.0         196                  2
# 39                 13                     7.0         196                  2
# 40                  9                     8.0         196                  1
# 41                 14                     8.0         196                  2
# 42                 12                     7.0         196                  2
# 43                 11                     7.0         196                  1
# 44                 14                     7.0         196                  1
# 45                 10                     6.0         196                  1
# 46                 11                     7.0         196                  1
# 47                 12                     8.0         196                  1
# 48                 10                     6.0         196                  1
# 49                  9                     7.0         196                  1
# 50                 10                     9.0         196                  1
# 51                 16                     4.0         196                  1
# 52                 14                     9.0         196                  2
# 53                  9                     5.0         196                  2
# 54                 11                    14.0         196                  3
# 55                 14                    14.0         196                  1
# 56                  9                    14.0         196                  2
# 57                 20                    30.0         196                  1
# 58                 15                     NaN         196                  6
# 59                 10                     5.0         196                  2
# 60                 11                    16.0         196                  1
# 61                  9                    13.0         196                  5
# 62                 10                    30.0         196                  1
# 63                 11                     1.0         196                  1
# 64                 11                    12.0         196                  1
# 65                 13                     7.0         196                  1
# 66                 15                     8.0         196                  1
# 67                  9                    25.0         196                  7
# 68                 14                     5.0         196                  1
# 69                  9                    30.0         196                  1
# 70                 13                    15.0         196                  2
# 71                 13                    30.0         196                  4
# 72                 11                    30.0         196                  1
# 73                  8                     8.0         196                  2
# 74                 17                     9.0         196                  5
#
#     reordered  ... aisle_id department_id  prices    price_range_loc  \
# 0           0  ...       77             7     9.0  Mid-range product
# 1           1  ...       77             7     9.0  Mid-range product
# 2           1  ...       77             7     9.0  Mid-range product
# 3           1  ...       77             7     9.0  Mid-range product
# 4           1  ...       77             7     9.0  Mid-range product
# 5           1  ...       77             7     9.0  Mid-range product
# 6           1  ...       77             7     9.0  Mid-range product
# 7           1  ...       77             7     9.0  Mid-range product
# 8           1  ...       77             7     9.0  Mid-range product
# 9           1  ...       77             7     9.0  Mid-range product
# 10          0  ...       77             7     9.0  Mid-range product
# 11          1  ...       77             7     9.0  Mid-range product
# 12          1  ...       77             7     9.0  Mid-range product
# 13          1  ...       77             7     9.0  Mid-range product
# 14          1  ...       77             7     9.0  Mid-range product
# 15          0  ...       77             7     9.0  Mid-range product
# 16          1  ...       77             7     9.0  Mid-range product
# 17          1  ...       77             7     9.0  Mid-range product
# 18          0  ...       77             7     9.0  Mid-range product
# 19          0  ...       77             7     9.0  Mid-range product
# 20          1  ...       77             7     9.0  Mid-range product
# 21          0  ...       77             7     9.0  Mid-range product
# 22          1  ...       77             7     9.0  Mid-range product
# 23          0  ...       77             7     9.0  Mid-range product
# 24          1  ...       77             7     9.0  Mid-range product
# 25          1  ...       77             7     9.0  Mid-range product
# 26          1  ...       77             7     9.0  Mid-range product
# 27          1  ...       77             7     9.0  Mid-range product
# 28          1  ...       77             7     9.0  Mid-range product
# 29          1  ...       77             7     9.0  Mid-range product
# 30          1  ...       77             7     9.0  Mid-range product
# 31          1  ...       77             7     9.0  Mid-range product
# 32          1  ...       77             7     9.0  Mid-range product
# 33          1  ...       77             7     9.0  Mid-range product
# 34          1  ...       77             7     9.0  Mid-range product
# 35          1  ...       77             7     9.0  Mid-range product
# 36          1  ...       77             7     9.0  Mid-range product
# 37          0  ...       77             7     9.0  Mid-range product
# 38          1  ...       77             7     9.0  Mid-range product
# 39          1  ...       77             7     9.0  Mid-range product
# 40          1  ...       77             7     9.0  Mid-range product
# 41          1  ...       77             7     9.0  Mid-range product
# 42          1  ...       77             7     9.0  Mid-range product
# 43          1  ...       77             7     9.0  Mid-range product
# 44          1  ...       77             7     9.0  Mid-range product
# 45          1  ...       77             7     9.0  Mid-range product
# 46          1  ...       77             7     9.0  Mid-range product
# 47          1  ...       77             7     9.0  Mid-range product
# 48          1  ...       77             7     9.0  Mid-range product
# 49          1  ...       77             7     9.0  Mid-range product
# 50          1  ...       77             7     9.0  Mid-range product
# 51          1  ...       77             7     9.0  Mid-range product
# 52          1  ...       77             7     9.0  Mid-range product
# 53          1  ...       77             7     9.0  Mid-range product
# 54          1  ...       77             7     9.0  Mid-range product
# 55          1  ...       77             7     9.0  Mid-range product
# 56          0  ...       77             7     9.0  Mid-range product
# 57          1  ...       77             7     9.0  Mid-range product
# 58          0  ...       77             7     9.0  Mid-range product
# 59          1  ...       77             7     9.0  Mid-range product
# 60          1  ...       77             7     9.0  Mid-range product
# 61          1  ...       77             7     9.0  Mid-range product
# 62          1  ...       77             7     9.0  Mid-range product
# 63          1  ...       77             7     9.0  Mid-range product
# 64          1  ...       77             7     9.0  Mid-range product
# 65          1  ...       77             7     9.0  Mid-range product
# 66          1  ...       77             7     9.0  Mid-range product
# 67          0  ...       77             7     9.0  Mid-range product
# 68          1  ...       77             7     9.0  Mid-range product
# 69          1  ...       77             7     9.0  Mid-range product
# 70          1  ...       77             7     9.0  Mid-range product
# 71          1  ...       77             7     9.0  Mid-range product
# 72          1  ...       77             7     9.0  Mid-range product
# 73          1  ...       77             7     9.0  Mid-range product
# 74          0  ...       77             7     9.0  Mid-range product
#
#        busiest_day  busiest_days busiest_period_of_day max_order  \
# 0   Regularly busy   Normal days        Average orders        10
# 1   Regularly busy  Slowest days         Fewest orders        10
# 2   Regularly busy  Slowest days           Most orders        10
# 3       Least busy  Slowest days         Fewest orders        10
# 4       Least busy  Slowest days           Most orders        10
# 5   Regularly busy   Normal days         Fewest orders        10
# 6   Regularly busy  Busiest days           Most orders        10
# 7   Regularly busy  Busiest days           Most orders        10
# 8   Regularly busy  Busiest days           Most orders        10
# 9       Least busy  Slowest days        Average orders        10
# 10  Regularly busy  Busiest days           Most orders        22
# 11  Regularly busy   Normal days           Most orders        22
# 12  Regularly busy   Normal days           Most orders        22
# 13  Regularly busy  Busiest days           Most orders        22
# 14  Regularly busy  Busiest days           Most orders        22
# 15  Regularly busy   Normal days           Most orders         9
# 16  Regularly busy   Normal days           Most orders         9
# 17      Least busy  Slowest days           Most orders         9
# 18  Regularly busy  Slowest days           Most orders        33
# 19  Regularly busy  Slowest days        Average orders        20
# 20  Regularly busy  Slowest days           Most orders        20
# 21      Least busy  Slowest days           Most orders        11
# 22      Least busy  Slowest days           Most orders        11
# 23  Regularly busy  Busiest days           Most orders        27
# 24  Regularly busy  Busiest days           Most orders        27
# 25  Regularly busy  Busiest days           Most orders        27
# 26  Regularly busy   Normal days           Most orders        27
# 27  Regularly busy   Normal days         Fewest orders        27
# 28  Regularly busy  Busiest days           Most orders        27
# 29  Regularly busy   Normal days           Most orders        27
# 30  Regularly busy   Normal days           Most orders        27
# 31  Regularly busy  Busiest days           Most orders        27
# 32  Regularly busy   Normal days           Most orders        27
# 33  Regularly busy   Normal days           Most orders        27
# 34  Regularly busy   Normal days           Most orders        27
# 35  Regularly busy  Slowest days        Average orders        27
# 36  Regularly busy   Normal days           Most orders        27
# 37  Regularly busy  Slowest days           Most orders        24
# 38  Regularly busy  Busiest days           Most orders        24
# 39  Regularly busy  Busiest days           Most orders        24
# 40  Regularly busy   Normal days           Most orders        24
# 41  Regularly busy  Slowest days           Most orders        24
# 42  Regularly busy  Slowest days           Most orders        24
# 43  Regularly busy   Normal days           Most orders        24
# 44  Regularly busy   Normal days           Most orders        24
# 45  Regularly busy  Busiest days           Most orders        24
# 46  Regularly busy  Busiest days           Most orders        24
# 47  Regularly busy   Normal days           Most orders        24
# 48  Regularly busy  Busiest days           Most orders        24
# 49  Regularly busy  Busiest days           Most orders        24
# 50      Least busy  Slowest days           Most orders        24
# 51  Regularly busy   Normal days           Most orders        24
# 52     Busiest day  Busiest days           Most orders        24
# 53  Regularly busy  Busiest days           Most orders        24
# 54  Regularly busy  Busiest days           Most orders        24
# 55  Regularly busy  Busiest days           Most orders        24
# 56  Regularly busy  Busiest days           Most orders         7
# 57  Regularly busy   Normal days         Fewest orders         7
# 58  Regularly busy  Slowest days           Most orders        19
# 59  Regularly busy   Normal days           Most orders        19
# 60     Busiest day  Busiest days           Most orders        19
# 61      Least busy  Slowest days           Most orders        19
# 62  Regularly busy  Busiest days           Most orders        19
# 63  Regularly busy   Normal days           Most orders        19
# 64  Regularly busy   Normal days           Most orders        19
# 65  Regularly busy  Busiest days           Most orders        19
# 66  Regularly busy   Normal days           Most orders        19
# 67     Busiest day  Busiest days           Most orders        14
# 68  Regularly busy   Normal days           Most orders        14
# 69  Regularly busy  Slowest days           Most orders        14
# 70      Least busy  Slowest days           Most orders        14
# 71  Regularly busy   Normal days           Most orders        14
# 72      Least busy  Slowest days           Most orders        14
# 73  Regularly busy   Normal days        Average orders        14
# 74  Regularly busy  Slowest days           Most orders         6
#
#         loyalty_flag  spending_habits
# 0       New customer         6.367797
# 1       New customer         6.367797
# 2       New customer         6.367797
# 3       New customer         6.367797
# 4       New customer         6.367797
# 5       New customer         6.367797
# 6       New customer         6.367797
# 7       New customer         6.367797
# 8       New customer         6.367797
# 9       New customer         6.367797
# 10  Regular customer         3.980556
# 11  Regular customer         3.980556
# 12  Regular customer         3.980556
# 13  Regular customer         3.980556
# 14  Regular customer         3.980556
# 15      New customer         8.372059
# 16      New customer         8.372059
# 17      New customer         8.372059
# 18  Regular customer         7.012683
# 19  Regular customer         8.137793
# 20  Regular customer         8.137793
# 21  Regular customer         7.444898
# 22  Regular customer         7.444898
# 23  Regular customer         6.356287
# 24  Regular customer         6.356287
# 25  Regular customer         6.356287
# 26  Regular customer         6.356287
# 27  Regular customer         6.356287
# 28  Regular customer         6.356287
# 29  Regular customer         6.356287
# 30  Regular customer         6.356287
# 31  Regular customer         6.356287
# 32  Regular customer         6.356287
# 33  Regular customer         6.356287
# 34  Regular customer         6.356287
# 35  Regular customer         6.356287
# 36  Regular customer         6.356287
# 37  Regular customer         7.656790
# 38  Regular customer         7.656790
# 39  Regular customer         7.656790
# 40  Regular customer         7.656790
# 41  Regular customer         7.656790
# 42  Regular customer         7.656790
# 43  Regular customer         7.656790
# 44  Regular customer         7.656790
# 45  Regular customer         7.656790
# 46  Regular customer         7.656790
# 47  Regular customer         7.656790
# 48  Regular customer         7.656790
# 49  Regular customer         7.656790
# 50  Regular customer         7.656790
# 51  Regular customer         7.656790
# 52  Regular customer         7.656790
# 53  Regular customer         7.656790
# 54  Regular customer         7.656790
# 55  Regular customer         7.656790
# 56      New customer         8.165385
# 57      New customer         8.165385
# 58  Regular customer         6.441221
# 59  Regular customer         6.441221
# 60  Regular customer         6.441221
# 61  Regular customer         6.441221
# 62  Regular customer         6.441221
# 63  Regular customer         6.441221
# 64  Regular customer         6.441221
# 65  Regular customer         6.441221
# 66  Regular customer         6.441221
# 67  Regular customer         8.028000
# 68  Regular customer         8.028000
# 69  Regular customer         8.028000
# 70  Regular customer         8.028000
# 71  Regular customer         8.028000
# 72  Regular customer         8.028000
# 73  Regular customer         8.028000
# 74      New customer         5.850725
#
# [75 rows x 22 columns]

# %% [markdown]
# Notes: All 75 rows are visible. This allows me to check whether my aggregation procedure was conducted successfully. Now that I've created my new column "spending_habits", it's time to set the "spending_flag" column.

# %%
# Create a flag that assigns a "spending" label to a user ID based on its corresponding average price value 
df_ords_prods_merge.loc[df_ords_prods_merge['spending_habits'] < 10, 'spending_flag'] = 'Low spender'

# %%
df_ords_prods_merge.loc[df_ords_prods_merge['spending_habits'] >= 10, 'spending_flag'] = 'High spender'

# %%
# Print frequency of the new "spending_flag" column using the value_counts() function 
df_ords_prods_merge['spending_flag'].value_counts(dropna = False)
# Out:
# Low spender     31770742
# High spender      634117
# Name: spending_flag, dtype: int64

# %% [markdown]
# Results: A customer is 50 times more likely to be a low spender (purchasing orders of items at low prices) on Instacart. <br>(31770742 / 634117 = 50.1)

# %% [markdown]
# # Step 7

# %% [markdown]
# Establishing Order Frequency Flag Criteria: <br>
# To create my "order_freq_flag" to identify and label types of customers (Frequent/Non-Frequent), I need some criteria. I'll look at users' ordering behavior and create a order frequency flag for each user based on the median in the "days_since_prior_order" column using the following: <br>
# <br>
# - If the median of “days_since_prior_order” is higher than 20, then the customer should be labeled a “Non-frequent customer.” <br>
# - If the median is higher than 10 and lower than or equal to 20, then the customer should be labeled a “Regular customer.”<br>
# - If the median is lower than or equal to 10, then the customer should be labeled a “Frequent customer.”<br>
# <br>
# I'll use the 3-step process as outlined in Steps 4 and 6 to compute Step 7. <br>
# Step 1 - Split the data into groups based on the “user_id” column.<br>
# Step 2 - Apply the transform() function on the “days_since_prior_order” column to generate the frequency of orders for each user.<br>
# Step 3 - Create a new column, “ordering_habits,” into which I’ll place the results of my aggregation.<br>
# <br>
# Once this process is complete, I can use the “ordering_habits” column to create another new column that assigns a order frequency flag to each customer according to the criteria (via the loc() function).

# %%
# Complete the 3-step process in a single line of code 
df_ords_prods_merge['ordering_habits'] = df_ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
# Check results in new column 
df_ords_prods_merge.head(10)
# Out:
#    order_id  user_id eval_set  order_number  order_day_of_week  \
# 0   2539329        1    prior             1                  2
# 1   2398795        1    prior             2                  3
# 2    473747        1    prior             3                  3
# 3   2254736        1    prior             4                  4
# 4    431534        1    prior             5                  4
# 5   3367565        1    prior             6                  2
# 6    550135        1    prior             7                  1
# 7   3108588        1    prior             8                  1
# 8   2295261        1    prior             9                  1
# 9   2550362        1    prior            10                  4
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  7                    15.0         196                  1
# 2                 12                    21.0         196                  1
# 3                  7                    29.0         196                  1
# 4                 15                    28.0         196                  1
# 5                  7                    19.0         196                  1
# 6                  9                    20.0         196                  1
# 7                 14                    14.0         196                  2
# 8                 16                     0.0         196                  4
# 9                  8                    30.0         196                  1
#
#    reordered  ... prices    price_range_loc     busiest_day  busiest_days  \
# 0          0  ...    9.0  Mid-range product  Regularly busy   Normal days
# 1          1  ...    9.0  Mid-range product  Regularly busy  Slowest days
# 2          1  ...    9.0  Mid-range product  Regularly busy  Slowest days
# 3          1  ...    9.0  Mid-range product      Least busy  Slowest days
# 4          1  ...    9.0  Mid-range product      Least busy  Slowest days
# 5          1  ...    9.0  Mid-range product  Regularly busy   Normal days
# 6          1  ...    9.0  Mid-range product  Regularly busy  Busiest days
# 7          1  ...    9.0  Mid-range product  Regularly busy  Busiest days
# 8          1  ...    9.0  Mid-range product  Regularly busy  Busiest days
# 9          1  ...    9.0  Mid-range product      Least busy  Slowest days
#
#    busiest_period_of_day max_order  loyalty_flag spending_habits  \
# 0         Average orders        10  New customer        6.367797
# 1          Fewest orders        10  New customer        6.367797
# 2            Most orders        10  New customer        6.367797
# 3          Fewest orders        10  New customer        6.367797
# 4            Most orders        10  New customer        6.367797
# 5          Fewest orders        10  New customer        6.367797
# 6            Most orders        10  New customer        6.367797
# 7            Most orders        10  New customer        6.367797
# 8            Most orders        10  New customer        6.367797
# 9         Average orders        10  New customer        6.367797
#
#   spending_flag  ordering_habits
# 0   Low spender             20.5
# 1   Low spender             20.5
# 2   Low spender             20.5
# 3   Low spender             20.5
# 4   Low spender             20.5
# 5   Low spender             20.5
# 6   Low spender             20.5
# 7   Low spender             20.5
# 8   Low spender             20.5
# 9   Low spender             20.5
#
# [10 rows x 24 columns]

# %% [markdown]
# Notes: "ordering_habits" column has been created and cells are computed. Next, I'll recheck results with 100 rows to see more users and their ordering habits.

# %%
df_ords_prods_merge.head(100)
# Out:
#     order_id  user_id eval_set  order_number  order_day_of_week  \
# 0    2539329        1    prior             1                  2
# 1    2398795        1    prior             2                  3
# 2     473747        1    prior             3                  3
# 3    2254736        1    prior             4                  4
# 4     431534        1    prior             5                  4
# 5    3367565        1    prior             6                  2
# 6     550135        1    prior             7                  1
# 7    3108588        1    prior             8                  1
# 8    2295261        1    prior             9                  1
# 9    2550362        1    prior            10                  4
# 10   2968173       15    prior            15                  1
# 11   1870022       15    prior            17                  2
# 12   1911383       15    prior            18                  2
# 13   2715276       15    prior            21                  1
# 14    487368       15    prior            22                  1
# 15   2293453       19    prior             2                  5
# 16   1973799       19    prior             5                  6
# 17    532817       19    prior             7                  4
# 18   1573906       21    prior            10                  3
# 19   1593000       31    prior            10                  3
# 20   2231262       31    prior            17                  3
# 21   2580647       43    prior             6                  4
# 22   2187180       43    prior             9                  4
# 23   2497897       52    prior             1                  1
# 24   1318871       52    prior             2                  1
# 25   1261384       52    prior             3                  1
# 26    580568       52    prior             5                  2
# 27   2428073       52    prior             7                  2
# 28    342306       52    prior             9                  1
# 29   1520353       52    prior            10                  2
# 30   2542086       52    prior            11                  2
# 31    944694       52    prior            12                  1
# 32   1268191       52    prior            15                  2
# 33   1122089       52    prior            17                  2
# 34   1498922       52    prior            18                  2
# 35    180919       52    prior            19                  3
# 36   2695875       52    prior            21                  5
# 37   3205960       67    prior             1                  3
# 38    970922       67    prior             2                  1
# 39    596585       67    prior             3                  1
# 40   2037087       67    prior             4                  2
# 41   2474111       67    prior             5                  3
# 42   1568481       67    prior             6                  3
# 43   2048527       67    prior             8                  2
# 44   2389031       67    prior             9                  2
# 45   2378562       67    prior            10                  1
# 46   1515698       67    prior            11                  1
# 47   1928050       67    prior            12                  2
# 48   1949274       67    prior            13                  1
# 49    551869       67    prior            14                  1
# 50    768572       67    prior            16                  4
# 51    150528       67    prior            18                  5
# 52     29758       67    prior            19                  0
# 53   1558976       67    prior            21                  1
# 54    863974       67    prior            22                  1
# 55   2308399       67    prior            23                  1
# 56   2759128       81    prior             3                  1
# 57   1812985       81    prior             5                  2
# 58   1889835       82    prior             1                  3
# 59    499460       82    prior             3                  5
# 60   2728456       82    prior             4                  0
# 61   2653743       82    prior             6                  4
# 62   1358880       82    prior             9                  1
# 63    343588       82    prior            10                  2
# 64   3034663       82    prior            15                  2
# 65    147262       82    prior            18                  1
# 66   3144004       82    prior            19                  2
# 67   2126069       98    prior             3                  0
# 68   2210120       98    prior             7                  5
# 69    681011       98    prior             9                  3
# 70   2846344       98    prior            11                  4
# 71    747431       98    prior            12                  6
# 72   2383054       98    prior            13                  4
# 73   1993729       98    prior            14                  5
# 74   1403849      109    prior             3                  3
# 75    520620      120    prior             1                  3
# 76   3273029      120    prior             3                  2
# 77   1861943      185    prior             2                  1
# 78   2040988      195    prior             1                  1
# 79   1680569      195    prior             8                  1
# 80    276171      195    prior            19                  5
# 81   2744976      195    prior            22                  5
# 82   2781919      195    prior            25                  1
# 83   1738718      195    prior            31                  2
# 84   3058369      195    prior            34                  3
# 85   1485596      195    prior            37                  2
# 86    417035      195    prior            40                  3
# 87   1615297      195    prior            47                  5
# 88   1765587      195    prior            52                  3
# 89    745908      195    prior            57                  4
# 90   2505656      222    prior            17                  2
# 91   3268370      222    prior            38                  5
# 92   2016711      290    prior             9                  5
# 93   2706088      290    prior            28                  6
# 94   1952286      331    prior             6                  5
# 95   3226575      360    prior             1                  5
# 96   1469869      377    prior             3                  5
# 97   1927023      387    prior             2                  4
# 98    858092      420    prior             4                  1
# 99    119314      420    prior             5                  3
#
#     order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                   8                     NaN         196                  1
# 1                   7                    15.0         196                  1
# 2                  12                    21.0         196                  1
# 3                   7                    29.0         196                  1
# 4                  15                    28.0         196                  1
# 5                   7                    19.0         196                  1
# 6                   9                    20.0         196                  1
# 7                  14                    14.0         196                  2
# 8                  16                     0.0         196                  4
# 9                   8                    30.0         196                  1
# 10                  9                     7.0         196                  2
# 11                 16                     8.0         196                  6
# 12                 11                     7.0         196                  1
# 13                  9                     7.0         196                  1
# 14                 10                    14.0         196                  1
# 15                 14                     6.0         196                  3
# 16                 12                     8.0         196                 15
# 17                 17                     6.0         196                  1
# 18                 10                     6.0         196                  2
# 19                  8                     7.0         196                 17
# 20                 11                     8.0         196                 14
# 21                 16                     4.0         196                  9
# 22                 12                     3.0         196                  1
# 23                  9                     NaN         196                  4
# 24                 10                     7.0         196                  5
# 25                 10                     7.0         196                  3
# 26                 10                     8.0         196                  6
# 27                  7                     8.0         196                  5
# 28                 11                     7.0         196                  5
# 29                 10                     8.0         196                  4
# 30                  9                     7.0         196                  3
# 31                 16                     6.0         196                  7
# 32                 11                     8.0         196                  3
# 33                 10                     6.0         196                  4
# 34                 10                    14.0         196                  6
# 35                  8                     8.0         196                  4
# 36                 10                    30.0         196                  1
# 37                 11                     NaN         196                  1
# 38                 15                     5.0         196                  2
# 39                 13                     7.0         196                  2
# 40                  9                     8.0         196                  1
# 41                 14                     8.0         196                  2
# 42                 12                     7.0         196                  2
# 43                 11                     7.0         196                  1
# 44                 14                     7.0         196                  1
# 45                 10                     6.0         196                  1
# 46                 11                     7.0         196                  1
# 47                 12                     8.0         196                  1
# 48                 10                     6.0         196                  1
# 49                  9                     7.0         196                  1
# 50                 10                     9.0         196                  1
# 51                 16                     4.0         196                  1
# 52                 14                     9.0         196                  2
# 53                  9                     5.0         196                  2
# 54                 11                    14.0         196                  3
# 55                 14                    14.0         196                  1
# 56                  9                    14.0         196                  2
# 57                 20                    30.0         196                  1
# 58                 15                     NaN         196                  6
# 59                 10                     5.0         196                  2
# 60                 11                    16.0         196                  1
# 61                  9                    13.0         196                  5
# 62                 10                    30.0         196                  1
# 63                 11                     1.0         196                  1
# 64                 11                    12.0         196                  1
# 65                 13                     7.0         196                  1
# 66                 15                     8.0         196                  1
# 67                  9                    25.0         196                  7
# 68                 14                     5.0         196                  1
# 69                  9                    30.0         196                  1
# 70                 13                    15.0         196                  2
# 71                 13                    30.0         196                  4
# 72                 11                    30.0         196                  1
# 73                  8                     8.0         196                  2
# 74                 17                     9.0         196                  5
# 75                 11                     NaN         196                  2
# 76                  8                    19.0         196                  2
# 77                 12                    25.0         196                 10
# 78                 14                     NaN         196                  2
# 79                  9                     4.0         196                  2
# 80                 11                     3.0         196                  2
# 81                 10                     7.0         196                  2
# 82                 14                     4.0         196                  1
# 83                  8                     4.0         196                  2
# 84                 10                     6.0         196                  2
# 85                 15                     0.0         196                  2
# 86                 16                     2.0         196                  2
# 87                 10                     2.0         196                  2
# 88                 12                     2.0         196                  3
# 89                 11                     3.0         196                  3
# 90                 12                     1.0         196                  2
# 91                 15                     1.0         196                  6
# 92                 19                     6.0         196                  8
# 93                 10                     7.0         196                 16
# 94                 16                    30.0         196                  8
# 95                 12                     NaN         196                  1
# 96                 17                     3.0         196                  9
# 97                 10                    22.0         196                  3
# 98                 19                    30.0         196                  2
# 99                 19                    16.0         196                  2
#
#     reordered  ... prices    price_range_loc     busiest_day  busiest_days  \
# 0           0  ...    9.0  Mid-range product  Regularly busy   Normal days
# 1           1  ...    9.0  Mid-range product  Regularly busy  Slowest days
# 2           1  ...    9.0  Mid-range product  Regularly busy  Slowest days
# 3           1  ...    9.0  Mid-range product      Least busy  Slowest days
# 4           1  ...    9.0  Mid-range product      Least busy  Slowest days
# 5           1  ...    9.0  Mid-range product  Regularly busy   Normal days
# 6           1  ...    9.0  Mid-range product  Regularly busy  Busiest days
# 7           1  ...    9.0  Mid-range product  Regularly busy  Busiest days
# 8           1  ...    9.0  Mid-range product  Regularly busy  Busiest days
# 9           1  ...    9.0  Mid-range product      Least busy  Slowest days
# 10          0  ...    9.0  Mid-range product  Regularly busy  Busiest days
# 11          1  ...    9.0  Mid-range product  Regularly busy   Normal days
# 12          1  ...    9.0  Mid-range product  Regularly busy   Normal days
# 13          1  ...    9.0  Mid-range product  Regularly busy  Busiest days
# 14          1  ...    9.0  Mid-range product  Regularly busy  Busiest days
# 15          0  ...    9.0  Mid-range product  Regularly busy   Normal days
# 16          1  ...    9.0  Mid-range product  Regularly busy   Normal days
# 17          1  ...    9.0  Mid-range product      Least busy  Slowest days
# 18          0  ...    9.0  Mid-range product  Regularly busy  Slowest days
# 19          0  ...    9.0  Mid-range product  Regularly busy  Slowest days
# 20          1  ...    9.0  Mid-range product  Regularly busy  Slowest days
# 21          0  ...    9.0  Mid-range product      Least busy  Slowest days
# 22          1  ...    9.0  Mid-range product      Least busy  Slowest days
# 23          0  ...    9.0  Mid-range product  Regularly busy  Busiest days
# 24          1  ...    9.0  Mid-range product  Regularly busy  Busiest days
# 25          1  ...    9.0  Mid-range product  Regularly busy  Busiest days
# 26          1  ...    9.0  Mid-range product  Regularly busy   Normal days
# 27          1  ...    9.0  Mid-range product  Regularly busy   Normal days
# 28          1  ...    9.0  Mid-range product  Regularly busy  Busiest days
# 29          1  ...    9.0  Mid-range product  Regularly busy   Normal days
# 30          1  ...    9.0  Mid-range product  Regularly busy   Normal days
# 31          1  ...    9.0  Mid-range product  Regularly busy  Busiest days
# 32          1  ...    9.0  Mid-range product  Regularly busy   Normal days
# 33          1  ...    9.0  Mid-range product  Regularly busy   Normal days
# 34          1  ...    9.0  Mid-range product  Regularly busy   Normal days
# 35          1  ...    9.0  Mid-range product  Regularly busy  Slowest days
# 36          1  ...    9.0  Mid-range product  Regularly busy   Normal days
# 37          0  ...    9.0  Mid-range product  Regularly busy  Slowest days
# 38          1  ...    9.0  Mid-range product  Regularly busy  Busiest days
# 39          1  ...    9.0  Mid-range product  Regularly busy  Busiest days
# 40          1  ...    9.0  Mid-range product  Regularly busy   Normal days
# 41          1  ...    9.0  Mid-range product  Regularly busy  Slowest days
# 42          1  ...    9.0  Mid-range product  Regularly busy  Slowest days
# 43          1  ...    9.0  Mid-range product  Regularly busy   Normal days
# 44          1  ...    9.0  Mid-range product  Regularly busy   Normal days
# 45          1  ...    9.0  Mid-range product  Regularly busy  Busiest days
# 46          1  ...    9.0  Mid-range product  Regularly busy  Busiest days
# 47          1  ...    9.0  Mid-range product  Regularly busy   Normal days
# 48          1  ...    9.0  Mid-range product  Regularly busy  Busiest days
# 49          1  ...    9.0  Mid-range product  Regularly busy  Busiest days
# 50          1  ...    9.0  Mid-range product      Least busy  Slowest days
# 51          1  ...    9.0  Mid-range product  Regularly busy   Normal days
# 52          1  ...    9.0  Mid-range product     Busiest day  Busiest days
# 53          1  ...    9.0  Mid-range product  Regularly busy  Busiest days
# 54          1  ...    9.0  Mid-range product  Regularly busy  Busiest days
# 55          1  ...    9.0  Mid-range product  Regularly busy  Busiest days
# 56          0  ...    9.0  Mid-range product  Regularly busy  Busiest days
# 57          1  ...    9.0  Mid-range product  Regularly busy   Normal days
# 58          0  ...    9.0  Mid-range product  Regularly busy  Slowest days
# 59          1  ...    9.0  Mid-range product  Regularly busy   Normal days
# 60          1  ...    9.0  Mid-range product     Busiest day  Busiest days
# 61          1  ...    9.0  Mid-range product      Least busy  Slowest days
# 62          1  ...    9.0  Mid-range product  Regularly busy  Busiest days
# 63          1  ...    9.0  Mid-range product  Regularly busy   Normal days
# 64          1  ...    9.0  Mid-range product  Regularly busy   Normal days
# 65          1  ...    9.0  Mid-range product  Regularly busy  Busiest days
# 66          1  ...    9.0  Mid-range product  Regularly busy   Normal days
# 67          0  ...    9.0  Mid-range product     Busiest day  Busiest days
# 68          1  ...    9.0  Mid-range product  Regularly busy   Normal days
# 69          1  ...    9.0  Mid-range product  Regularly busy  Slowest days
# 70          1  ...    9.0  Mid-range product      Least busy  Slowest days
# 71          1  ...    9.0  Mid-range product  Regularly busy   Normal days
# 72          1  ...    9.0  Mid-range product      Least busy  Slowest days
# 73          1  ...    9.0  Mid-range product  Regularly busy   Normal days
# 74          0  ...    9.0  Mid-range product  Regularly busy  Slowest days
# 75          0  ...    9.0  Mid-range product  Regularly busy  Slowest days
# 76          1  ...    9.0  Mid-range product  Regularly busy   Normal days
# 77          0  ...    9.0  Mid-range product  Regularly busy  Busiest days
# 78          0  ...    9.0  Mid-range product  Regularly busy  Busiest days
# 79          1  ...    9.0  Mid-range product  Regularly busy  Busiest days
# 80          1  ...    9.0  Mid-range product  Regularly busy   Normal days
# 81          1  ...    9.0  Mid-range product  Regularly busy   Normal days
# 82          1  ...    9.0  Mid-range product  Regularly busy  Busiest days
# 83          1  ...    9.0  Mid-range product  Regularly busy   Normal days
# 84          1  ...    9.0  Mid-range product  Regularly busy  Slowest days
# 85          1  ...    9.0  Mid-range product  Regularly busy   Normal days
# 86          1  ...    9.0  Mid-range product  Regularly busy  Slowest days
# 87          1  ...    9.0  Mid-range product  Regularly busy   Normal days
# 88          1  ...    9.0  Mid-range product  Regularly busy  Slowest days
# 89          1  ...    9.0  Mid-range product      Least busy  Slowest days
# 90          0  ...    9.0  Mid-range product  Regularly busy   Normal days
# 91          1  ...    9.0  Mid-range product  Regularly busy   Normal days
# 92          0  ...    9.0  Mid-range product  Regularly busy   Normal days
# 93          1  ...    9.0  Mid-range product  Regularly busy   Normal days
# 94          0  ...    9.0  Mid-range product  Regularly busy   Normal days
# 95          0  ...    9.0  Mid-range product  Regularly busy   Normal days
# 96          0  ...    9.0  Mid-range product  Regularly busy   Normal days
# 97          0  ...    9.0  Mid-range product      Least busy  Slowest days
# 98          0  ...    9.0  Mid-range product  Regularly busy  Busiest days
# 99          1  ...    9.0  Mid-range product  Regularly busy  Slowest days
#
#     busiest_period_of_day max_order      loyalty_flag spending_habits  \
# 0          Average orders        10      New customer        6.367797
# 1           Fewest orders        10      New customer        6.367797
# 2             Most orders        10      New customer        6.367797
# 3           Fewest orders        10      New customer        6.367797
# 4             Most orders        10      New customer        6.367797
# 5           Fewest orders        10      New customer        6.367797
# 6             Most orders        10      New customer        6.367797
# 7             Most orders        10      New customer        6.367797
# 8             Most orders        10      New customer        6.367797
# 9          Average orders        10      New customer        6.367797
# 10            Most orders        22  Regular customer        3.980556
# 11            Most orders        22  Regular customer        3.980556
# 12            Most orders        22  Regular customer        3.980556
# 13            Most orders        22  Regular customer        3.980556
# 14            Most orders        22  Regular customer        3.980556
# 15            Most orders         9      New customer        8.372059
# 16            Most orders         9      New customer        8.372059
# 17            Most orders         9      New customer        8.372059
# 18            Most orders        33  Regular customer        7.012683
# 19         Average orders        20  Regular customer        8.137793
# 20            Most orders        20  Regular customer        8.137793
# 21            Most orders        11  Regular customer        7.444898
# 22            Most orders        11  Regular customer        7.444898
# 23            Most orders        27  Regular customer        6.356287
# 24            Most orders        27  Regular customer        6.356287
# 25            Most orders        27  Regular customer        6.356287
# 26            Most orders        27  Regular customer        6.356287
# 27          Fewest orders        27  Regular customer        6.356287
# 28            Most orders        27  Regular customer        6.356287
# 29            Most orders        27  Regular customer        6.356287
# 30            Most orders        27  Regular customer        6.356287
# 31            Most orders        27  Regular customer        6.356287
# 32            Most orders        27  Regular customer        6.356287
# 33            Most orders        27  Regular customer        6.356287
# 34            Most orders        27  Regular customer        6.356287
# 35         Average orders        27  Regular customer        6.356287
# 36            Most orders        27  Regular customer        6.356287
# 37            Most orders        24  Regular customer        7.656790
# 38            Most orders        24  Regular customer        7.656790
# 39            Most orders        24  Regular customer        7.656790
# 40            Most orders        24  Regular customer        7.656790
# 41            Most orders        24  Regular customer        7.656790
# 42            Most orders        24  Regular customer        7.656790
# 43            Most orders        24  Regular customer        7.656790
# 44            Most orders        24  Regular customer        7.656790
# 45            Most orders        24  Regular customer        7.656790
# 46            Most orders        24  Regular customer        7.656790
# 47            Most orders        24  Regular customer        7.656790
# 48            Most orders        24  Regular customer        7.656790
# 49            Most orders        24  Regular customer        7.656790
# 50            Most orders        24  Regular customer        7.656790
# 51            Most orders        24  Regular customer        7.656790
# 52            Most orders        24  Regular customer        7.656790
# 53            Most orders        24  Regular customer        7.656790
# 54            Most orders        24  Regular customer        7.656790
# 55            Most orders        24  Regular customer        7.656790
# 56            Most orders         7      New customer        8.165385
# 57          Fewest orders         7      New customer        8.165385
# 58            Most orders        19  Regular customer        6.441221
# 59            Most orders        19  Regular customer        6.441221
# 60            Most orders        19  Regular customer        6.441221
# 61            Most orders        19  Regular customer        6.441221
# 62            Most orders        19  Regular customer        6.441221
# 63            Most orders        19  Regular customer        6.441221
# 64            Most orders        19  Regular customer        6.441221
# 65            Most orders        19  Regular customer        6.441221
# 66            Most orders        19  Regular customer        6.441221
# 67            Most orders        14  Regular customer        8.028000
# 68            Most orders        14  Regular customer        8.028000
# 69            Most orders        14  Regular customer        8.028000
# 70            Most orders        14  Regular customer        8.028000
# 71            Most orders        14  Regular customer        8.028000
# 72            Most orders        14  Regular customer        8.028000
# 73         Average orders        14  Regular customer        8.028000
# 74            Most orders         6      New customer        5.850725
# 75            Most orders         3      New customer        9.385714
# 76         Average orders         3      New customer        9.385714
# 77            Most orders         6      New customer        7.715000
# 78            Most orders        58    Loyal customer        7.149730
# 79            Most orders        58    Loyal customer        7.149730
# 80            Most orders        58    Loyal customer        7.149730
# 81            Most orders        58    Loyal customer        7.149730
# 82            Most orders        58    Loyal customer        7.149730
# 83         Average orders        58    Loyal customer        7.149730
# 84            Most orders        58    Loyal customer        7.149730
# 85            Most orders        58    Loyal customer        7.149730
# 86            Most orders        58    Loyal customer        7.149730
# 87            Most orders        58    Loyal customer        7.149730
# 88            Most orders        58    Loyal customer        7.149730
# 89            Most orders        58    Loyal customer        7.149730
# 90            Most orders        70    Loyal customer        6.862397
# 91            Most orders        70    Loyal customer        6.862397
# 92         Average orders        51    Loyal customer        7.285597
# 93            Most orders        51    Loyal customer        7.285597
# 94            Most orders         8      New customer        7.705128
# 95            Most orders         3      New customer       10.006250
# 96            Most orders         3      New customer        8.496552
# 97            Most orders         8      New customer        7.396610
# 98         Average orders        22  Regular customer        7.387805
# 99         Average orders        22  Regular customer        7.387805
#
#    spending_flag  ordering_habits
# 0    Low spender             20.5
# 1    Low spender             20.5
# 2    Low spender             20.5
# 3    Low spender             20.5
# 4    Low spender             20.5
# 5    Low spender             20.5
# 6    Low spender             20.5
# 7    Low spender             20.5
# 8    Low spender             20.5
# 9    Low spender             20.5
# 10   Low spender             10.0
# 11   Low spender             10.0
# 12   Low spender             10.0
# 13   Low spender             10.0
# 14   Low spender             10.0
# 15   Low spender              6.0
# 16   Low spender              6.0
# 17   Low spender              6.0
# 18   Low spender              7.5
# 19   Low spender              6.0
# 20   Low spender              6.0
# 21   Low spender             10.0
# 22   Low spender             10.0
# 23   Low spender              8.0
# 24   Low spender              8.0
# 25   Low spender              8.0
# 26   Low spender              8.0
# 27   Low spender              8.0
# 28   Low spender              8.0
# 29   Low spender              8.0
# 30   Low spender              8.0
# 31   Low spender              8.0
# 32   Low spender              8.0
# 33   Low spender              8.0
# 34   Low spender              8.0
# 35   Low spender              8.0
# 36   Low spender              8.0
# 37   Low spender              7.0
# 38   Low spender              7.0
# 39   Low spender              7.0
# 40   Low spender              7.0
# 41   Low spender              7.0
# 42   Low spender              7.0
# 43   Low spender              7.0
# 44   Low spender              7.0
# 45   Low spender              7.0
# 46   Low spender              7.0
# 47   Low spender              7.0
# 48   Low spender              7.0
# 49   Low spender              7.0
# 50   Low spender              7.0
# 51   Low spender              7.0
# 52   Low spender              7.0
# 53   Low spender              7.0
# 54   Low spender              7.0
# 55   Low spender              7.0
# 56   Low spender             30.0
# 57   Low spender             30.0
# 58   Low spender             11.5
# 59   Low spender             11.5
# 60   Low spender             11.5
# 61   Low spender             11.5
# 62   Low spender             11.5
# 63   Low spender             11.5
# 64   Low spender             11.5
# 65   Low spender             11.5
# 66   Low spender             11.5
# 67   Low spender             25.0
# 68   Low spender             25.0
# 69   Low spender             25.0
# 70   Low spender             25.0
# 71   Low spender             25.0
# 72   Low spender             25.0
# 73   Low spender             25.0
# 74   Low spender             26.0
# 75   Low spender             19.0
# 76   Low spender             19.0
# 77   Low spender             25.0
# 78   Low spender              4.0
# 79   Low spender              4.0
# 80   Low spender              4.0
# 81   Low spender              4.0
# 82   Low spender              4.0
# 83   Low spender              4.0
# 84   Low spender              4.0
# 85   Low spender              4.0
# 86   Low spender              4.0
# 87   Low spender              4.0
# 88   Low spender              4.0
# 89   Low spender              4.0
# 90   Low spender              5.0
# 91   Low spender              5.0
# 92   Low spender              7.0
# 93   Low spender              7.0
# 94   Low spender             30.0
# 95  High spender              4.0
# 96   Low spender             16.5
# 97   Low spender              8.0
# 98   Low spender              7.0
# 99   Low spender              7.0
#
# [100 rows x 24 columns]

# %% [markdown]
# Notes: All 100 rows are visible. This allows me to check whether my aggregation procedure was conducted successfully. Now that I've created my new column "ordering_habits", it's time to set the "order_freq_flag" column.

# %%
# Create a flag that assigns a "order frequency" label to a user ID based on its corresponding median order frequency value 
df_ords_prods_merge.loc[df_ords_prods_merge['ordering_habits'] > 20, 'order_freq_flag'] = 'Non-frequent customer'

# %%
df_ords_prods_merge.loc[(df_ords_prods_merge['ordering_habits'] > 10) & (df_ords_prods_merge['ordering_habits'] <= 20), 'order_freq_flag'] = 'Regular customer'

# %%
df_ords_prods_merge.loc[df_ords_prods_merge['ordering_habits'] <= 10, 'order_freq_flag'] = 'Frequent customer'

# %%
# Print frequency of the new "order_freq_flag" column using the value_counts() function 
df_ords_prods_merge['order_freq_flag'].value_counts(dropna = False)
# Out:
# Frequent customer        21559853
# Regular customer          7208564
# Non-frequent customer     3636437
# NaN                             5
# Name: order_freq_flag, dtype: int64

# %% [markdown]
# Results: More than half of customers are frequent customers. There are 5 missing values which is preassumed as not enough data is available to classify 5 users in the system.

# %% [markdown]
# # Steps 8, 9, 10

# %% [markdown]
# The notebook is clean and organized!

# %%
# Export dataframe in a pickle file 
df_ords_prods_merge.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merge_flagged.pkl'))

# %% [markdown]
# The notebook is saved in the Scripts folder and submitted for review.
